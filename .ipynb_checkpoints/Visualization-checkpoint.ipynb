# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import os

tf.get_logger().setLevel('ERROR')           # Suppress TensorFlow logging (2)

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

def download_images():
#     base_url = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/test_images/'
#     filenames = ['image1.jpg', 'image2.jpg']
    base_url = 'workspace/training_demo/images/train/'
    
    filenames = []
    for root, directories, file in os.walk(base_url):
        for i in range(120, 300):
            if(file[i].endswith(".jpg")):
                print(os.path.join(file[i]))
                filenames.append(os.path.join(file[i]))
#     filenames = ['evraz 120.jpg', 'evraz 250.jpg']
    image_paths = []
    for filename in filenames:
#         image_path = tf.keras.utils.get_file(fname=filename,
#                                             origin=base_url + filename,
#                                             untar=False)
        image_path = base_url + filename
        image_path = pathlib.Path(image_path)
        image_paths.append(str(image_path))
    return image_paths

IMAGE_PATHS = download_images()
# Out:
# evraz 254.jpg
# evraz 266.jpg
# evraz 269.jpg
# evraz 271.jpg
# evraz 278.jpg
# evraz 280.jpg
# evraz 282.jpg
# evraz 318.jpg
# evraz 338.jpg
# evraz 346.jpg
# evraz 347.jpg
# evraz 348.jpg
# evraz 349.jpg
# evraz 350.jpg
# evraz 351.jpg
# evraz 352.jpg
# evraz 353.jpg
# evraz 355.jpg
# evraz 356.jpg
# evraz 357.jpg
# evraz 358.jpg
# evraz 359.jpg
# evraz 360.jpg
# evraz 362.jpg
# evraz 363.jpg
# evraz 364.jpg
# evraz 367.jpg
# evraz 369.jpg
# evraz 374.jpg
# evraz 375.jpg
# evraz 376.jpg
# evraz 377.jpg
# evraz 378.jpg
# evraz 387.jpg
# evraz 391.jpg
# evraz 398.jpg
# evraz 417.jpg
# evraz 418.jpg
# evraz 419.jpg
# evraz 420.jpg
# evraz 421.jpg
# evraz 422.jpg
# evraz 426.jpg
# evraz 428.jpg
# evraz 430.jpg
# evraz 432.jpg
# evraz 443.jpg
# evraz 445.jpg
# evraz 449.jpg
# evraz 471.jpg
# evraz 475.jpg
# evraz 481.jpg
# evraz 488.jpg
# evraz 494.jpg
# evraz 495.jpg
# evraz 498.jpg
# evraz 501.jpg
# evraz 503.jpg
# evraz 510.jpg
# evraz 514.jpg
# evraz 515.jpg
# evraz 517.jpg
# evraz 518.jpg
# evraz 520.jpg
# evraz 522.jpg
# evraz 524.jpg
# evraz 525.jpg
# evraz 535.jpg
# evraz 537.jpg
# evraz 541.jpg
# evraz 543.jpg
# evraz 544.jpg
# evraz 555.jpg
# evraz 559.jpg
# evraz 597.jpg
# evraz 598.jpg
# evraz 599.jpg
# evraz 601.jpg
# evraz 603.jpg
# evraz 605.jpg
# evraz 606.jpg
# evraz 608.jpg
# evraz 612.jpg
# evraz 614.jpg
# evraz 617.jpg
# evraz 621.jpg
# evraz 624.jpg
# evraz 627.jpg
# evraz 632.jpg
# evraz 633.jpg

# %%
# # Download and extract model
# def download_model(model_name, model_date):
#     base_url = 'http://download.tensorflow.org/models/object_detection/tf2/'
#     model_file = model_name + '.tar.gz'
#     model_dir = tf.keras.utils.get_file(fname=model_name,
#                                         origin=base_url + model_date + '/' + model_file,
#                                         untar=True)
#     return str(model_dir)

# MODEL_DATE = '20200711'
# MODEL_NAME = 'covsh_net-32'
# PATH_TO_MODEL_DIR = download_model(MODEL_NAME, MODEL_DATE)
PATH_TO_MODEL_DIR = 'workspace/training_demo/exported-models/my_model/'

# %%
# # Download labels file
# def download_labels(filename):
#     base_url = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/data/'
#     label_dir = tf.keras.utils.get_file(fname=filename,
#                                         origin=base_url + filename,
#                                         untar=False)
#     label_dir = pathlib.Path(label_dir)
#     return str(label_dir)

PATH_TO_LABELS = 'workspace/training_demo/annotations/'

# %%
LABEL_FILENAME = 'label_map.pbtxt'

# %%
# !pip install object_detection
# Out:
# Collecting object_detection
#   Downloading object_detection-0.0.3-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: pillow in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from object_detection) (8.4.0)
# Requirement already satisfied: jupyter in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from object_detection) (1.0.0)
# Requirement already satisfied: Cython in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from object_detection) (0.29.25)
# Requirement already satisfied: tensorflow in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from object_detection) (2.7.0)
# Requirement already satisfied: matplotlib in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from object_detection) (3.5.1)
# Collecting contextlib2
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting lxml
#   Using cached lxml-4.6.4-cp39-cp39-win_amd64.whl (3.5 MB)
# Requirement already satisfied: ipywidgets in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter->object_detection) (7.6.5)
# Requirement already satisfied: jupyter-console in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter->object_detection) (6.4.0)
# Requirement already satisfied: nbconvert in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter->object_detection) (6.3.0)
# Requirement already satisfied: ipykernel in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter->object_detection) (6.6.0)
# Requirement already satisfied: notebook in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter->object_detection) (6.4.6)
# Requirement already satisfied: qtconsole in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter->object_detection) (5.2.1)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipykernel->jupyter->object_detection) (5.1.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipykernel->jupyter->object_detection) (7.30.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipykernel->jupyter->object_detection) (7.1.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipykernel->jupyter->object_detection) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipykernel->jupyter->object_detection) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipykernel->jupyter->object_detection) (6.1)
# Requirement already satisfied: backcall in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.2.0)
# Requirement already satisfied: decorator in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (5.1.0)
# Requirement already satisfied: colorama in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (3.0.24)
# Requirement already satisfied: setuptools>=18.5 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (59.5.0)
# Requirement already satisfied: pygments in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->object_detection) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->object_detection) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->object_detection) (0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->object_detection) (4.9.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->object_detection) (1.5.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter->object_detection) (302)
# Requirement already satisfied: wcwidth in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyter->object_detection) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter->object_detection) (1.15.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipywidgets->jupyter->object_detection) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipywidgets->jupyter->object_detection) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipywidgets->jupyter->object_detection) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from ipywidgets->jupyter->object_detection) (5.1.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->object_detection) (4.2.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->object_detection) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->object_detection) (0.18.0)
# Requirement already satisfied: prometheus-client in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from notebook->jupyter->object_detection) (0.12.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from notebook->jupyter->object_detection) (0.12.1)
# Requirement already satisfied: jinja2 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from notebook->jupyter->object_detection) (3.0.3)
# Requirement already satisfied: argon2-cffi in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from notebook->jupyter->object_detection) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from notebook->jupyter->object_detection) (1.8.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->object_detection) (1.1.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from argon2-cffi->notebook->jupyter->object_detection) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->object_detection) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->object_detection) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from jinja2->notebook->jupyter->object_detection) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->object_detection) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->object_detection) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->object_detection) (1.19.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->object_detection) (4.28.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->object_detection) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib->object_detection) (21.3)
# Requirement already satisfied: bleach in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbconvert->jupyter->object_detection) (4.1.0)
# Requirement already satisfied: testpath in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbconvert->jupyter->object_detection) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbconvert->jupyter->object_detection) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbconvert->jupyter->object_detection) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbconvert->jupyter->object_detection) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbconvert->jupyter->object_detection) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from nbconvert->jupyter->object_detection) (0.5.9)
# Requirement already satisfied: webencodings in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from bleach->nbconvert->jupyter->object_detection) (0.5.1)
# Requirement already satisfied: qtpy in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from qtconsole->jupyter->object_detection) (1.11.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (3.7.4.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (3.3.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (0.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (0.22.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (1.34.1)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (12.0.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (2.7.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (0.37.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (3.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (1.1.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (0.4.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (1.12)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow->object_detection) (3.19.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->object_detection) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->object_detection) (2.3.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->object_detection) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->object_detection) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->object_detection) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->object_detection) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard~=2.6->tensorflow->object_detection) (2.26.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->object_detection) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->object_detection) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->object_detection) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->object_detection) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow->object_detection) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow->object_detection) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->object_detection) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->object_detection) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->object_detection) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->object_detection) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->object_detection) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kira\anaconda3\envs\tensorflow\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->object_detection) (3.1.1)
# Installing collected packages: lxml, contextlib2, object-detection
# Successfully installed contextlib2-21.6.0 lxml-4.6.4 object-detection-0.0.3

# %%
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "saved_model"

print('Loading model...', end='')
start_time = time.time()

# Load saved model and build the detection function
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11932/2257970851.py in <module>
#       1 import time
# ----> 2 from object_detection.utils import label_map_util
#       3 from object_detection.utils import visualization_utils as viz_utils
#       4
#       5 PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "saved_model"
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\object_detection\utils\label_map_util.py in <module>
#      19 import tensorflow as tf
#      20 from google.protobuf import text_format
# ---> 21 from object_detection.protos import string_int_label_map_pb2
#      22
#      23
#
# ImportError: cannot import name 'string_int_label_map_pb2' from 'object_detection.protos' (C:\Users\Kira\anaconda3\envs\tensorflow\lib\site-packages\object_detection\protos\__init__.py)

# %%
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS + LABEL_FILENAME,
                                                                    use_display_name=True)

# %%
PATH_TO_VIDEO = "/home/user/Tensorflow/video/test.avi"

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
      path: the file path to the image

    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))


for image_path in IMAGE_PATHS:

    print('Running inference for {}... '.format(image_path), end='')

    image_np = load_image_into_numpy_array(image_path)
    
    print(np.expand_dims(image_np, 0).shape)
    
    # Things to try:
    # Flip horizontally
    # image_np = np.fliplr(image_np).copy()

    # Convert image to grayscale
    # image_np = np.tile(
    #     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)

    detections = detect_fn(input_tensor)
    
    print("hello")
    
    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimension.
    # We're only interested in the first num_detections.
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()
    
    print(detections['detection_scores'])
    
    viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=200,
            min_score_thresh=.30,
            agnostic_mode=False)

    plt.figure()
    plt.imshow(image_np_with_detections)
    print('Done')
plt.show()

# sphinx_gallery_thumbnail_number = 2
# Out:
# Running inference for workspace/training_demo/images/train/evraz 419.jpg... (1, 1080, 1920, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2341/3976079683.py in <module>
#      40     input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
#      41
# ---> 42     detections = detect_fn(input_tensor)
#      43
#      44     print("hello")
#
# ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py in _call_attribute(instance, *args, **kwargs)
#     699
#     700 def _call_attribute(instance, *args, **kwargs):
# --> 701   return instance.__call__(*args, **kwargs)
#     702
#     703
#
# ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~/anaconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _convert_inputs_to_signature(inputs, input_signature, flat_input_signature)
#    2980       flat_input_signature,
#    2981       flatten_inputs)):
# -> 2982     raise ValueError("Python inputs incompatible with input_signature:\n"
#    2983                      f"{format_error_message(inputs, input_signature)}.")
#    2984
#
# ValueError: Python inputs incompatible with input_signature:
#   inputs: (
#     tf.Tensor(
# [[[[102. 124. 122.]
#    [102. 124. 122.]
#    [103. 125. 123.]
#    ...
#    [ 23.  56.  91.]
#    [ 23.  56.  91.]
#    [ 23.  56.  91.]]
#
#   [[102. 124. 122.]
#    [102. 124. 122.]
#    [103. 125. 123.]
#    ...
#    [ 23.  56.  91.]
#    [ 23.  56.  91.]
#    [ 23.  56.  91.]]
#
#   [[102. 124. 122.]
#    [102. 124. 122.]
#    [103. 125. 123.]
#    ...
#    [ 23.  56.  91.]
#    [ 23.  56.  91.]
#    [ 23.  56.  91.]]
#
#   ...
#
#   [[ 90.  90.  90.]
#    [ 87.  87.  89.]
#    [ 83.  83.  85.]
#    ...
#    [ 25.  68. 100.]
#    [ 25.  68. 100.]
#    [ 25.  68. 100.]]
#
#   [[ 89.  87.  88.]
#    [ 89.  87.  90.]
#    [ 87.  85.  88.]
#    ...
#    [ 25.  68. 100.]
#    [ 25.  68. 100.]
#    [ 25.  68. 100.]]
#
#   [[ 69.  67.  68.]
#    [ 64.  62.  65.]
#    [ 62.  60.  63.]
#    ...
#    [ 25.  68. 100.]
#    [ 25.  68. 100.]
#    [ 25.  68. 100.]]]], shape=(1, 1080, 1920, 3), dtype=float32))
#   input_signature: (
#     TensorSpec(shape=(1, None, None, 3), dtype=tf.uint8, name='input_tensor')).
